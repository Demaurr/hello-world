# %% [markdown]
# <a href="https://colab.research.google.com/github/Brightlat/hello-world/blob/main/movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
movies = pd.read_csv("/content/drive/MyDrive/movies.csv",index_col=0, parse_dates=True)

# %%
movies
# Out:
#                            Name    Year  Story  Acting  Dialogs  \
# S.no
# 0                           NaN     NaN    NaN     NaN      NaN
# 1                     Godfather  1972.0    9.0    10.0      9.0
# 2          The Army of the Dead  2021.0    5.0     4.0      4.0
# 3                        Munich  2005.0    8.0     8.0      8.0
# 4                   Tell No One  2006.0    8.0     8.0      7.0
# ...                         ...     ...    ...     ...      ...
# 225                  Black Book  2006.0    7.5     6.5      6.7
# 226                   Benedetta  2021.0    6.5     7.0      6.0
# 227   Mother Joan Of The Angels  1961.0    7.3     7.5      7.3
# 228                  Babysitter  2022.0    6.0     6.0      6.5
# 229                     Ittefaq  2017.0    8.0     7.7      7.0
#
#       Cinematography  Music  Rating Language N-Scenes  \
# S.no
# 0                NaN    NaN     NaN      NaN      NaN
# 1                9.0    9.0     9.2  English    Maybe
# ...

# %%
movies["Avg-Rating"] = round((movies.Story + movies.Acting + movies.Music + movies.Dialogs + movies.Cinematography) / 5, 1)

# %%
movies[["Avg-Rating", "Rating"]]
# Out:
#       Avg-Rating  Rating
# S.no
# 0            NaN     NaN
# 1            9.2     9.2
# 2            5.0     5.0
# 3            8.0     8.0
# 4            7.4     7.4
# ...          ...     ...
# 225          7.1     7.1
# 226          6.5     6.5
# 227          7.5     7.5
# 228          6.3     6.3
# 229          7.5     7.5
#
# [230 rows x 2 columns]

# %%
movies.tail(20)
# Out:
#      S.no                            Name    Year  Story  Acting  Dialogs  \
# 210   210                    The Gray Man  2022.0    6.0     6.0      5.7
# 211   211                    Madrid, 1987  2011.0    5.7     6.0      5.0
# 212   212  The Coed And The Zombie Stoner  2014.0    3.0     2.0      2.0
# 213   213                   Lust, Caution  2007.0    7.5     7.5      7.0
# 214   214             Last Tango In Paris  1972.0    6.3     6.5      6.0
# 215   215                       Blackmail  2018.0    7.7     7.5      6.7
# 216   216              The Age Of Adaline  2015.0    7.0     7.0      6.7
# 217   217                   American Made  2017.0    7.7     7.7      7.0
# 218   218                       Searching  2018.0    8.0     7.5      7.0
# 219   219                   The Housemaid  2010.0    6.5     6.7      6.0
# 220   220                           Alien  1979.0    7.7     7.5      7.0
# 221   221                 Dressed To Kill  1980.0    7.3     7.3      7.0
# ...

# %%
movies[["Watched", "Name"]]
# Out:
#      Watched                       Name
# S.no
# 0        NaN                        NaN
# 1       2018                  Godfather
# 2     6/2021       The Army of the Dead
# 3     6/2021                     Munich
# 4       2021                Tell No One
# ...      ...                        ...
# 225   8/2022                 Black Book
# 226   8/2022                  Benedetta
# 227   8/2022  Mother Joan Of The Angels
# 228   8/2022                 Babysitter
# 229   8/2022                    Ittefaq
#
# [230 rows x 2 columns]

# %%
movies.plot()

# %%
movies[["Rating", "Year"]].plot()

# %%
movies.to_csv("/content/drive/MyDrive/m.csv")

# %%
plt.plot(movies.Rating, "o")

# %%
movies["A-Date"] = str(movies.Date + "/" + movies.Watched)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-57-29639ecaf538> in <module>
# ----> 1 movies["A-Date"] = str(movies.Date + "/" + movies.Watched)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# ...

# %%
movies[movies.notnull()]
# Out:
#                            Name    Year  Story  Acting  Dialogs  \
# S.no
# 0                           NaN     NaN    NaN     NaN      NaN
# 1                     Godfather  1972.0    9.0    10.0      9.0
# 2          The Army of the Dead  2021.0    5.0     4.0      4.0
# 3                        Munich  2005.0    8.0     8.0      8.0
# 4                   Tell No One  2006.0    8.0     8.0      7.0
# ...                         ...     ...    ...     ...      ...
# 225                  Black Book  2006.0    7.5     6.5      6.7
# 226                   Benedetta  2021.0    6.5     7.0      6.0
# 227   Mother Joan Of The Angels  1961.0    7.3     7.5      7.3
# 228                  Babysitter  2022.0    6.0     6.0      6.5
# 229                     Ittefaq  2017.0    8.0     7.7      7.0
#
#       Cinematography  Music  Rating Language N-Scenes  \
# S.no
# 0                NaN    NaN     NaN      NaN      NaN
# 1                9.0    9.0     9.2  English    Maybe
# ...

# %%
movies
# Out:
#                            Name    Year  Story  Acting  Dialogs  \
# S.no
# 0                           NaN     NaN    NaN     NaN      NaN
# 1                     Godfather  1972.0    9.0    10.0      9.0
# 2          The Army of the Dead  2021.0    5.0     4.0      4.0
# 3                        Munich  2005.0    8.0     8.0      8.0
# 4                   Tell No One  2006.0    8.0     8.0      7.0
# ...                         ...     ...    ...     ...      ...
# 225                  Black Book  2006.0    7.5     6.5      6.7
# 226                   Benedetta  2021.0    6.5     7.0      6.0
# 227   Mother Joan Of The Angels  1961.0    7.3     7.5      7.3
# 228                  Babysitter  2022.0    6.0     6.0      6.5
# 229                     Ittefaq  2017.0    8.0     7.7      7.0
#
#       Cinematography  Music  Rating Language N-Scenes  \
# S.no
# 0                NaN    NaN     NaN      NaN      NaN
# 1                9.0    9.0     9.2  English    Maybe
# ...
